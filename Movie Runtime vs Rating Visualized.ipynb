# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("complete_top_200_movies.csv")
df.head()
# Out:
#                                         Title  Lifetime Gross  Year  \
# 0                                      Avatar      2923706026  2009
# 1                           Avengers: Endgame      2799439100  2019
# 2                    Avatar: The Way of Water      2320250281  2022
# 3                                     Titanic      2264750694  1997
# 4  Star Wars: Episode VII - The Force Awakens      2071310218  2015
#
#                                       Title.1  Year.1  Rated     Released  \
# 0                                      Avatar    2009  PG-13  18 Dec 2009
# 1                           Avengers: Endgame    2019  PG-13  26 Apr 2019
# 2                    Avatar: The Way of Water    2022  PG-13  16 Dec 2022
# 3                                     Titanic    1997  PG-13  19 Dec 1997
# 4  Star Wars: Episode VII - The Force Awakens    2015  PG-13  18 Dec 2015
#
#    Runtime                       Genre                  Director  ...  \
# ...

# %%
#sorted_runtime = df.sort_values(by='Runtime', ascending = False)
# sorted_runtime['Runtime'].unique()
# Convert 'Runtime' column to strings
df['Runtime'] = df['Runtime'].astype(str)

df['Runtime'] = df['Runtime'].str.split().str[0].astype(int)
sorted_runtime = df.sort_values(by='Runtime')
sorted_runtime['Runtime'].unique()
# Out:
# array([ 83,  84,  86,  87,  88,  89,  90,  91,  92,  93,  94,  95,  96,
#         97,  98, 100, 101, 102, 103, 104, 105, 106, 107, 108, 110, 111,
#        112, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125,
#        126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138,
#        139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151,
#        152, 153, 154, 157, 158, 161, 162, 163, 164, 165, 166, 169, 176,
#        178, 179, 180, 181, 192, 194, 201])

# %%
import numpy as np
runtime = sorted_runtime['Runtime']
rating = sorted_runtime['imdbRating']

# Scatter plot
plt.scatter(runtime, rating, color='gold', edgecolor='black', label='Movie')

# Linear regression
m, b = np.polyfit(runtime, rating, 1)
plt.plot(runtime, m*runtime + b, color='purple', label='Regression Line')

# Labels and title
plt.xlabel('Runtime')
plt.ylabel('IMDb Score (Out of 10)')
plt.title('Movie Runtime vs IMDb Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend()

plt.savefig('movie_runtime_vs_imdb_score.png')

plt.show()

# %%
print(runtime.min())
print(runtime.max())
# Out:
# 83
# 201

# %%
money = sorted_runtime['Lifetime Gross']

# Scatter plot
plt.scatter(runtime, money, color='gold', edgecolor='black', label='Movie')

# Linear regression
m, b = np.polyfit(runtime, money, 1)
plt.plot(runtime, m*runtime + b, color='purple', label='Regression Line')

# Labels and title
plt.xlabel('Runtime')
plt.ylabel('Lifetime Grossing')
plt.title('Movie Runtime vs Lifetime Grossing')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.legend()

plt.savefig('movie_runtime_vs_lifetime_gross.png')

plt.show()
